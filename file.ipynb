# %%
# %pwd
# %cd tools/
# %pwd
# Out:
# /home/riccardo/Desktop/domain-decompositions/amsc-project/dd_project/tools
# /usr/lib/python3/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# '/home/riccardo/Desktop/domain-decompositions/amsc-project/dd_project/tools'

# %%
from plot import load_data, add_total_solve_time, plot_metric

df = load_data("../data/output/csv/results_seq_precs.csv")
df = add_total_solve_time(df)
df.head(30)
# Out:
#          n         prec  iters      residual  time_setup  time_solve  \
# 0    10000     identity   5000  2.809200e-13    0.000000    0.236499
# 1    10000  diag_jacobi   5000  2.809200e-13    0.000235    0.227656
# 2    10000     blockjac   2077  6.863610e-13    0.000558    0.348668
# 3    10000           as    196  7.122310e-13    0.000827    0.043489
# 4    20000     identity  10000  4.885220e-13    0.000000    0.860254
# 5    20000  diag_jacobi  10000  4.885220e-13    0.000380    0.896034
# 6    20000     blockjac   4114  7.887360e-13    0.000897    1.326380
# 7    20000           as    376  8.542320e-13    0.001871    0.157922
# 8    40000     identity  20000  9.546400e-13    0.000000    3.545550
# 9    40000  diag_jacobi  20000  9.546400e-13    0.000623    3.692190
# 10   40000     blockjac   8185  8.030660e-13    0.001112    5.405210
# 11   40000           as    729  4.473350e-13    0.003343    0.595702
# 12   80000     identity  40000  1.175740e-13    0.000000   14.148500
# ...

# %%
plot_metric(df, "iters", metric_label="Iterations")
plot_metric(df, "total_time", logy=True, metric_label="Total time [s]")
plot_metric(df, "time_per_iter", logy=True, metric_label="Time per iter [s]")
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot: xlabel='Matrix dimension n', ylabel='Time per iter [s]'>)
